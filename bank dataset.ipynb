# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [raw]
# **reading bank file into a dataframe**

# %%
bank=pd.read_csv(r"C:\Users\HP\EDA\dataset\bank.csv",sep=";")
bank
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
l1=bank.select_dtypes(include="object").columns
l1
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %% [markdown]
# **creating frequency table for each and every object in bank data frame**

# %%
job=[]
for i in bank["job"].unique():
    job.append(len(bank[bank["job"]==i]))

job_df=pd.DataFrame(zip(bank["job"].unique(),job),columns=["job","count"])
job_df.to_csv("jobs.csv",index=False)
pd.read_csv("jobs.csv")
# Out:
#               job  count
# 0      unemployed    128
# 1        services    417
# 2      management    969
# 3     blue-collar    946
# 4   self-employed    183
# 5      technician    768
# 6    entrepreneur    168
# 7          admin.    478
# 8         student     84
# 9       housemaid    112
# 10        retired    230
# 11        unknown     38

# %%
marital=[]
for i in bank["marital"].unique():
    marital.append(len(bank[bank["marital"]==i]))

marital_df=pd.DataFrame(zip(bank["marital"].unique(),marital),columns=["marital status","count"])
marital_df.to_csv("marital_status.csv",index=False)
pd.read_csv("marital_status.csv")
# Out:
#   marital status  count
# 0        married   2797
# 1         single   1196
# 2       divorced    528

# %%
edu=[]
for i in bank["education"].unique():
    edu.append(len(bank[bank["education"]==i]))

edu_df=pd.DataFrame(zip(bank["education"].unique(),edu),columns=["education","count"])
edu_df.to_csv("education.csv",index=False)
pd.read_csv("education.csv")
# Out:
#    education  count
# 0    primary    678
# 1  secondary   2306
# 2   tertiary   1350
# 3    unknown    187

# %%
house=[]
for i in bank["housing"].unique():
    house.append(len(bank[bank["housing"]==i]))

house_df=pd.DataFrame(zip(bank["housing"].unique(),house),columns=["housing","count"])
house_df.to_csv("housing.csv",index=False)
pd.read_csv("housing.csv")
# Out:
#   housing  count
# 0      no   1962
# 1     yes   2559

# %%
loan_list=[]
for i in bank["loan"].unique():
    loan_list.append(len(bank[bank["loan"]==i]))

loan_df=pd.DataFrame(zip(bank["loan"].unique(),loan_list),columns=["loan","count"])
loan_df.to_csv("loan.csv",index=False)
pd.read_csv("loan.csv")
# Out:
#   loan  count
# 0   no   3830
# 1  yes    691

# %%
c_list=[]
for i in bank["contact"].unique():
    c_list.append(len(bank[bank["contact"]==i]))

contact_df=pd.DataFrame(zip(bank["contact"].unique(),c_list),columns=["contact","count"])
contact_df.to_csv("contact.csv",index=False)
pd.read_csv("contact.csv")
# Out:
#      contact  count
# 0   cellular   2896
# 1    unknown   1324
# 2  telephone    301

# %%
month_list=[]
for i in bank["month"].unique():
    month_list.append(len(bank[bank["month"]==i]))

month_df=pd.DataFrame(zip(bank["month"].unique(),month_list),columns=["month","count"])
month_df.to_csv("month.csv",index=False)
pd.read_csv("month.csv")
# Out:
#    month  count
# 0    oct     80
# 1    may   1398
# 2    apr    293
# 3    jun    531
# 4    feb    222
# 5    aug    633
# 6    jan    148
# 7    jul    706
# 8    nov    389
# 9    sep     52
# 10   mar     49
# 11   dec     20

# %%
p_list=[]
for i in bank["poutcome"].unique():
    p_list.append(len(bank[bank["poutcome"]==i]))

p_df=pd.DataFrame(zip(bank["poutcome"].unique(),p_list),columns=["outcome","count"])
p_df.to_csv("outcome.csv",index=False)
pd.read_csv("outcome.csv")
# Out:
#    outcome  count
# 0  unknown   3705
# 1  failure    490
# 2    other    197
# 3  success    129

# %%
y_list=[]
for i in bank["y"].unique():
    y_list.append(len(bank[bank["y"]==i]))

y_df=pd.DataFrame(zip(bank["y"].unique(),y_list),columns=["Y","count"])
y_df.to_csv("y.csv",index=False)
pd.read_csv("y.csv")
# Out:
#      Y  count
# 0   no   4000
# 1  yes    521

# %% [markdown]
# **Analysis of bank dataset by using valuecounts and plot package**

# %%
bank_l=[]
for i in bank.select_dtypes(include="object"):
    b=bank[i].value_counts()
    k=b.keys()
    v=b.values
    cols=["labels","count"]
    bank_df=pd.DataFrame(zip(k,v),columns=cols)
    bank_l.append(bank_df)
    path=r"C:\Users\HP\valuecount"
    bank_df.to_csv(f"{path}\\{i}.csv",index=False)

# %%
l1=list(bank.select_dtypes(include="object").columns)

# %%
import matplotlib.pyplot as plt
for i,j in zip(bank_l,l1):
    plt.figure(figsize=(19,8))
    plt.bar("labels","count",data=i)
    plt.title(f"bar graph--- {j}")
    plt.xlabel("class")
    plt.ylabel("frequency")
    path=r"C:\Users\HP\valuecount"
    plt.savefig(f"{path}\\{j}.jpg")
    
    plt.show()
