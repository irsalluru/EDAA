# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
visa_df=pd.read_csv(r"C:\Users\HP\EDA\dataset\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
# total number of applicants whose visa got denied
len(visa_df[visa_df["case_status"]=="Denied"])
# Out:
# 8462

# %%
#total number of applicants whose visa is certified
len(visa_df[visa_df["case_status"]!="Denied"])
# Out:
# 17018

# %%
y=visa_df[visa_df["continent"]=="Asia"]
y["case_status"].value_counts()
# Out:
# case_status
# Certified    11012
# Denied        5849
# Name: count, dtype: int64

# %%
x=visa_df["continent"].unique()
count_cert=[]
count_deni=[]
for i in continent:
    
    y=visa_df[visa_df["continent"]==i]
   
    count_cert.append(len(y[y["case_status"]=="Certified"]))
    count_deni.append(len(y[y["case_status"]!="Certified"]))

df1=pd.DataFrame(zip(x,count_cert),columns=["Continent","Certified Count"])
df2=pd.DataFrame(zip(x,count_deni),columns=["Continent","Denied Count"])

print(df1)
print()
print(df2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 count_cert=[]
#       3 count_deni=[]
# ----> 4 for i in continent:
#       6     y=visa_df[visa_df["continent"]==i]
#       8     count_cert.append(len(y[y["case_status"]=="Certified"]))
#
# NameError: name 'continent' is not defined

# %%
y=visa_df["case_status"]=="Denied"
df=visa_df[y]
df["continent"].value_counts()

# %% [markdown]
# ** BI variate analysis**
# - We already seen univariate analysis
# - we performed categorical column analysis
#       - FREQUENCY TABLE
#       - bar chart
#       - relative frequency table
#       - pie chart
#
# - we performed the numerical column analysis
#       - histogram
#       - distribution plot
#       - box plot
#       - oulier analysis
#       - filling outliers
#
# - now we will do categorical, categorical Analysis
# - numerical-numerical analysis
# - categorical-numerical analysis
#
#
#
# -

# %% [markdown]
# ***Ctergorical - Categorical***

# %%
num_col=visa_df.select_dtypes(exclude="object").columns
cat_col=visa_df.select_dtypes(include="object").columns

# %%
visa_df["continent"].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
visa_df["case_status"].value_counts()
# Out:
# case_status
# Certified    17018
# Denied        8462
# Name: count, dtype: int64

# %%
# find the cerified observations continent wise
con1= visa_df["continent"]=="Asia"
con2= visa_df["case_status"]=="Certified"
con3= con1 & con2
visa_df[con3]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 5         EZYV06      Asia              Master's                  Y
# 6         EZYV07      Asia            Bachelor's                  N
# 8         EZYV09      Asia            Bachelor's                  N
# 10        EZYV11      Asia              Master's                  N
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
try:
    new_dir=os.path.join(os.getcwd(),"categorical_categorical")
    os.makedirs(new_dir)
except Exception as e:
    print(e)

# %%
os.path.exists(new_dir)
# Out:
# True

# %%
# find the cerified observations continent wise
count1=[]
for i in visa_df["continent"].unique():
    con1= visa_df["continent"]==i
    con2= visa_df["case_status"]=="Certified"
    con3= con1 & con2
    count1.append(len(visa_df[con3]))

df=pd.DataFrame(zip(visa_df["continent"].unique(),count1),columns=["continent","count"])
df.to_csv(f"{new_dir}/certified.csv", index=False)
df
# Out:
#        continent  count
# 0           Asia  11012
# 1         Africa    397
# 2  North America   2037
# 3         Europe   2957
# 4  South America    493
# 5        Oceania    122

# %%
count2=[]
for i in visa_df["continent"].unique():
    con1= visa_df["continent"]==i
    con2= visa_df["case_status"]!="Certified"
    con3= con1 & con2
    count2.append(len(visa_df[con3]))

df=pd.DataFrame(zip(visa_df["continent"].unique(),count2),columns=["continent","count"])
df.to_csv(f"{new_dir}/Denied.csv", index=False)
df

df2=pd.DataFrame(zip(count1,count2),index=visa_df["continent"].unique(),columns=["certified","Denied"])
df2.to_csv(f"{new_dir}\certified_denied.csv")
df2
# Out:
#                certified  Denied
# Asia               11012    5849
# Africa               397     154
# North America       2037    1255
# Europe              2957     775
# South America        493     359
# Oceania              122      70

# %% [markdown]
# **cross tab**
# - the above data frame we can make by using  **cross tab**
# - it is avaliable in pandas
# - it takes two arguments
#     - index
#     - argument
#
# - in above dataframe index column is continent
# - in above daat frame data column is case status

# %%
df3.pd.crosstab(visa_df["continent"],visa_df["case_status"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9600\3261576825.py in ?()
# ----> 1 df3.pd.crosstab(visa_df["continent"],visa_df["case_status"])
#
# ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'pd'

# %%
df3.plot(kind="bar")
# Out:
# <Axes: xlabel='continent'>

# %%
data=[visa_df["education_of_employee"],visa_df["case_status"]]
df5=pd.crosstab(visa_df["continent"],data)
df5
# Out:
# education_of_employee Bachelor's        Doctorate        High School         \
# case_status            Certified Denied Certified Denied   Certified Denied
# continent
# Africa                        81     62        43     11          23     43
# Asia                        4407   2761       780    143         676   1614
# Europe                      1040    259       788     58         162    328
# North America                641    584       207     51         210    191
# Oceania                       38     28        19      3          19     17
# South America                160    173        75     14          74     63
#
# education_of_employee  Master's
# case_status           Certified Denied
# continent
# Africa                      250     38
# Asia                       5149   1331
# Europe                      967    130
# North America               979    429
# Oceania                      46     22
# South America               184    109

# %%
data=[visa_df["case_status"],visa_df["education_of_employee"],]
df4=pd.crosstab(visa_df["continent"],data)
df4
# Out:
# case_status            Certified                                    Denied  \
# education_of_employee Bachelor's Doctorate High School Master's Bachelor's
# continent
# Africa                        81        43          23      250         62
# Asia                        4407       780         676     5149       2761
# Europe                      1040       788         162      967        259
# North America                641       207         210      979        584
# Oceania                       38        19          19       46         28
# South America                160        75          74      184        173
#
# case_status
# education_of_employee Doctorate High School Master's
# continent
# Africa                       11          43       38
# Asia                        143        1614     1331
# Europe                       58         328      130
# North America                51         191      429
# Oceania                       3          17       22
# ...

# %%
df5.plot(kind="bar")
# Out:
# <Axes: xlabel='continent'>

# %%
df4.plot(kind="bar")
# Out:
# <Axes: xlabel='continent'>

# %% [markdown]
# **numerical vs numerical**

# %%
num_cols=visa_df.select_dtypes(exclude="object").columns

# %%
x=visa_df["prevailing_wage"]
y=visa_df["no_of_employees"]
z=visa_df["yr_of_estab"]
plt.figure(figsize=(10,8))

plt.scatter(y,z)

# %% [markdown]
# - implement the covariance function
# - covariance vs corelation
#     - covariance will tell about the columns have relation or not
#     - covariance will explain about relation satatus
#         - positive reation
#         - negative reelation
#         - no realtion
#     - corealtion tells about how much realtion between two variables
#         - it denotes with "r"
#         - r varies from -1 to +1
#         - -1 to 0 indicates negative rea;tion
#         - 0 to +1 indicates positive realtion
#         0 indicates no relation

# %% [markdown]
# **method name is corr**

# %%
corr_data=visa_df.corr(numeric_only=True)

# %% [markdown]
# **Heat map**
# - heat map is one of the important visualization method, to show the matrix
# - it is under  **seaborn** package
# - in every matrix we have heighest values and lowest values avaliable
# - Heat map will give color visuailizations
# - also it provides color bar ,which color indicates which value

# %%
sns.heatmap(corr_data,annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(corr_data,annot=True,cmap='magma')
# Out:
# <Axes: >

# %% [markdown]
# - by seeing the graph we migth not say the relation status
# - it is best practice to get the percentage of the relation  using corealtion
# - all 3 columns having approx zero percentage of realtion
# - which indicates all the columns having no realtion
# - no relation means indeoendent to each other
# - In ML we except the input columns should be independent each other
# - corr method gives matrix veiw
# - we have 3 coluns 3*3 total 9 fieds
# - if a data has 20 columns then 20*20 total 400 feilds
# - thats's why alwaya go with Heat map visialization

# %% [markdown]
# **label encoder**
# - it is a method to convert categorical to numerical data
# - Label Encoder i a same way, how we did in above
# - the for loop map method we explored
# - it i sunder **sickit-learn** we usally call **sklearn
# - under sklear we have class called preprocessing
# - because currently we are doing data preprocessing only
# - under preprocessing class we have a metod called as **Label Encoder**
# - sklearn
#         - preprocessing
#             - Label Encoder
# * an sklearn package has 3 steps
#     step1- Read package
#     step2 -save the package
#     step3-apply shift transform to data

# %%
visa_df=pd.read_csv(r"C:\Users\HP\EDA\dataset\Visadataset.csv")

# %%
cat_cols=visa_df.select_dtypes(include="object").columns
num_cols=visa_df.select_dtypes(exclude="object").columns

# %%
#Step1: read the package
from sklearn.preprocessing import LabelEncoder
#step2:save the package/ call the method
le=LabelEncoder()
#step3: Appply fit ransform on data
for i in cat_cols:
    visa_df[i]=le.fit_transform(visa_df[i])
visa_df
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0            0          1                      2                   0
# 1            1          1                      3                   1
# 2            2          1                      0                   0
# 3            3          1                      0                   0
# 4            4          0                      3                   1
# ...        ...        ...                    ...                 ...
# 25475    17204          1                      0                   1
# 25476    17205          1                      2                   1
# 25477    17206          1                      3                   1
# 25478    17207          1                      3                   1
# 25479    17209          1                      0                   1
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                          0            14513         2007
# ...

# %% [markdown]
# **fit and transform**
# - fit means develop the logic
# - transform means process the logic
# - if we observe in map method first we developed dictionary lo;gic
# - then we apply that dictionary to column
# - developing the dictionary is akind of fit
# - apply the dictionary to column means we are transforming the data cat to num
# - whenever we are transforming or changing the data then use **fit transform**
# - if we are not changing the data the only apply **fit**

# %% [markdown]
# **np.where**
# - using np.where also we can chage the Categorical to numerical data
# - but np.where is only for binary condition
# - np.where is same as if and else
# - if condition is true : will aply True value
# - if condition is false: will apply False value
# - A column should have only 2 values

# %%
visa_df=pd.read_csv(r"C:\Users\HP\EDA\dataset\Visadataset.csv")
visa_df["case_status"]=np.where(visa_df["case_status"]=="Certified",0,1)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# **one hot encoder**
# * one hot means if one will be ON ,another will be OFF
# * ON represents 1
# * OFF represents with 0
# * For example case_status has two unique labels
# * - cetifed
#   - denied
# - one hat encoder creates new columns which is equa to number of unique labels
# - - case_Status_certified
#   - case_status_denied
#
# |case_status|case_status_certified|case_Status_denied|
# |-|-|-|
# |Denied|0|1|
# |certfied|1|0|
